# %%
# criando um Spark Session com suporte a Hive
from pyspark.sql import SparkSession
spark_session = SparkSession.builder.enableHiveSupport().getOrCreate()
# Duas maneiras de acessar o contexto do spark a partir da sessão do spark
spark_context = spark_session._sc
spark_context = spark_session.sparkContext
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark_context
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: </div>
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1382381753923521#setting/sparkui/0909-220305-flows435/driver-5579421691201229763">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
# pode fazer a conexão com kafka, e gravar no HBase
# Interface/meio de comunicação com Spark e o stream
from pyspark.streaming import StreamingContext
ssc = StreamingContext(sc, 1)
#deixa a conexão aberta
lines = ssc.socketTextStream('localhost', 9999)
# mostra em loop até encerrar a operação
counts = lines.flatMap(lambda line: line.split(" ")).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a+b)
counts.pprint()
ssc.start()
ssc.awaitTermination()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-------------------------------------------
# Time: 2021-09-09 22:04:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-09 22:04:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-09 22:04:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-09 22:04:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-09 22:04:49
# -------------------------------------------
#
# ...
